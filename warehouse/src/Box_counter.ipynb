# %%
import numpy as np
import os
from collections import defaultdict

# Threshold for x_center similarity to consider them "stacked"
x_threshold = 0.02
folder_path = "./"  

# Get all .txt files in the folder and sort them alphabetically
txt_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".txt")])

# Iterate over sorted .txt files
for filename in txt_files:
    file_path = os.path.join(folder_path, filename)

    try:
        yolo_data = np.loadtxt(file_path)

        if yolo_data.size == 0:  
            print(f"{filename}: No data found.")
            continue

        if yolo_data.ndim == 1:  # Handle single-line YOLO files
            yolo_data = np.expand_dims(yolo_data, axis=0)

        # Group bounding boxes by x_center similarity
        x_groups = defaultdict(list)

        for entry in yolo_data:
            class_id, x_center, y_center, width, height = entry
            found_group = False

            for key in x_groups.keys():
                if abs(x_center - key) < x_threshold:
                    x_groups[key].append((x_center, y_center, width, height))
                    found_group = True
                    break

            if not found_group:
                x_groups[x_center].append((x_center, y_center, width, height))

        # Find the maximum number of stacked boxes
        max_stacked = max(len(boxes) for boxes in x_groups.values())
        print(f"{filename}: {max_stacked}")

    except Exception as e:
        print(f"Error processing {filename}: {e}")
# Out:
# 1.txt: 6
# 10.txt: 3
# 11.txt: 6
# 12.txt: 5
# 13.txt: 4
# 14.txt: 5
# 15.txt: 2
# 16.txt: 3
# 17.txt: 4
# 18.txt: 4
# 19.txt: 4
# 2.txt: 2
# 20.txt: 3
# 21.txt: 3
# 22.txt: 3
# 23.txt: 6
# 3.txt: 2
# 4.txt: 5
# 5.txt: 1
# 6.txt: 3
# 7.txt: 2
# 8.txt: 1
# 9.txt: 3
# WhatsApp Image 2025-02-14 at 12.10.21 (1).txt: 2
# WhatsApp Image 2025-02-14 at 12.10.21 (2).txt: 2
# WhatsApp Image 2025-02-14 at 12.10.21.txt: 3
# WhatsApp Image 2025-02-14 at 12.10.22 (1).txt: 1
# WhatsApp Image 2025-02-14 at 12.10.22 (2).txt: 3
# WhatsApp Image 2025-02-14 at 12.10.22 (3).txt: 2
# WhatsApp Image 2025-02-14 at 12.10.22.txt: 4
# WhatsApp Image 2025-02-14 at 12.10.23 (1).txt: 3
# WhatsApp Image 2025-02-14 at 12.10.23 (2).txt: 3
# WhatsApp Image 2025-02-14 at 12.10.23 (3).txt: 6
# WhatsApp Image 2025-02-14 at 12.10.23.txt: 1
# WhatsApp Image 2025-02-14 at 12.10.24 (1).txt: 4
# WhatsApp Image 2025-02-14 at 12.10.24 (2).txt: 5
# WhatsApp Image 2025-02-14 at 12.10.24.txt: 5
# WhatsApp Image 2025-02-14 at 12.10.25 (1).txt: 3
# WhatsApp Image 2025-02-14 at 12.10.25 (2).txt: 4
# WhatsApp Image 2025-02-14 at 12.10.25.txt: 2
# WhatsApp Image 2025-02-14 at 12.10.26 (1).txt: 4
# WhatsApp Image 2025-02-14 at 12.10.26 (2).txt: 3
# WhatsApp Image 2025-02-14 at 12.10.26 (3).txt: 3
# WhatsApp Image 2025-02-14 at 12.10.26.txt: 4
# WhatsApp Image 2025-02-14 at 12.10.27 (1).txt: 6
# WhatsApp Image 2025-02-14 at 12.10.27.txt: 3
